# %% [markdown]
# <a href="https://colab.research.google.com/github/ryu-bit676/0-0-0/blob/main/game_rpg_py_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Hero:
    # Constructor: Dijalankan saat Hero baru dibuat
    def __init__(self, name, hp, attack_power):
        self.name = name # Nama Hero
        self.hp = hp # Nyawa (Health Point)
        self.attack_power = attack_power # Kekuatan Serangan

    # Method untuk menampilkan info hero
    def info(self):
        print(f"Hero: {self.name} | HP: {self.hp} | Power: {self.attack_power}")

# -- Main Program --
# Membuat Object (Instansiasi)
hero1 = Hero("Layla", 100, 15)
hero2 = Hero("Zilong", 120, 20)

hero1.hp = 500
print(hero1.hp)

# Memanggil Method
hero1.info()
hero2.info()
# Out:
# 500
# Hero: Layla | HP: 500 | Power: 15
# Hero: Zilong | HP: 120 | Power: 20

# %% [markdown]
# method hero1.hp = 500 akan merubah hero1 = hero menjadi 500 hp dan akan menyalinnya menggunakan print(hero1.hp)

# %%
# Define the functions that will become methods
def _serang_method(self, lawan):
    print(f"{self.name} menyerang {lawan.name}!")
    lawan.diserang(self.attack_power)

def _diserang_method(self, damage):
    self.hp -= damage
    print(f"{self.name} terkena damage {damage}. Sisa HP: {self.hp}")

# Dynamically add these functions as methods to the Hero class
Hero.serang = _serang_method
Hero.diserang = _diserang_method

# Tambah kode Output di akhir program
print("\n--- Pertarungan Dimulai ---")
hero1.serang(hero2) # Layla menyerang Zilong
hero2.serang(hero1) # Zilong membalas
# Out:
# --- Pertarungan Dimulai ---
# Layla menyerang Zilong!
# Zilong terkena damage 15. Sisa HP: 105
# Zilong menyerang Layla!
# Layla terkena damage 20. Sisa HP: 480

# %% [markdown]
# karena objek tersebut memiliki data dan perilaku yang dibutuhkan untuk melakukan serangan.

# %%
# Class Mage adalah anak dari class Hero
class Mage(Hero):
    def __init__(self, name, hp, attack_power, mana):
        # Memanggil constructor milik Parent (Hero)
        super().__init__(name, hp, attack_power)
        self.mana = mana

    def info(self):
        print(f"{self.name} [Mage] | HP: {self.hp} | Mana: {self.mana}")

    # Mage punya skill khusus
    def skill_fireball(self, lawan):
        if self.mana >= 20:
            print(f"{self.name} menggunakan Fireball ke {lawan.name}!")
            self.mana -= 20
            lawan.diserang(self.attack_power * 2) # Damage 2x lipat
        else:
            print(f"{self.name} gagal skill! Mana tidak cukup.")

# -- Main Program Baru --
print("\n--- Update Class Hero ---")
eudora = Mage("Eudora", 80, 30, 100)
balmond = Hero("Balmond", 200, 10)
eudora.info()
eudora.serang(balmond) # Serangan biasa (warisan dari Hero)
eudora.skill_fireball(balmond) # Skill khusus Mage

# %% [markdown]
# karena method super() berperan sebagai media penyimpanan

# %%
class Hero:
    def __init__(self, nama, hp_awal):
        self.nama = nama
        # Enkapsulasi: HP bersifat Private (hanya bisa diakses di dalam class ini)
        self.__hp = hp_awal

    # GETTER: Cara resmi melihat HP
    def get_hp(self):
        return self.__hp


    def diserang(self, damage):
        # Kita pakai setter/getter bahkan di dalam class sendiri agar aman
        sisa_hp = self.get_hp() - damage
        self.set_hp(sisa_hp)
        print(f"{self.nama} terkena damage {damage}. Sisa HP: {self.get_hp()}")

# -- Uji Coba --
hero1 = Hero("Layla", 100)
# hero1.__hp = 9999 # GAGAL (Tidak akan mengubah hp asli)
# print(hero1.__hp) # ERROR (Tidak bisa dibaca langsung)
hero1.set_hp(-100) # Coba set negatif
print(hero1.get_hp()) # Output: 0 (Karena dicegat oleh logika Setter)

print(f"Mencoba akses paksa : {hero1._Hero_hp}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2492/529140205.py in <cell line: 0>()
#      20 # hero1.__hp = 9999 # GAGAL (Tidak akan mengubah hp asli)
#      21 # print(hero1.__hp) # ERROR (Tidak bisa dibaca langsung)
# ---> 22 hero1.set_hp(-100) # Coba set negatif
#      23 print(hero1.get_hp()) # Output: 0 (Karena dicegat oleh logika Setter)
#      24
#
# AttributeError: 'Hero' object has no attribute 'set_hp'

# %% [markdown]
# karna mencoba mengakses nama yang salah dan berubah menjadi error

# %% [markdown]
# karena method setter berfungsi sebagai perantara pengganti

# %%
from abc import ABC, abstractmethod
# 1. Interface / Abstract Class
# Ini adalah KONTRAK. Semua turunan wajib punya method di bawah ini.
class GameUnit(ABC):
    @abstractmethod
    def serang(self, target):
        pass

    @abstractmethod
    def info(self):
        pass

# 2. Implementasi pada Class Konkret
class Hero(GameUnit):
    def __init__(self, nama):
        self.nama = nama

    # Kita WAJIB membuat method serang, kalau tidak akan Error
    def serang(self, target):
        print(f"Hero {self.nama} menebas {target}!")

    def info(self):
        print(f"Saya adalah Hero: {self.nama}")

class Monster(GameUnit):
    def __init__(self, jenis):
        self.jenis = jenis

    # Implementasi serang versi Monster
    def serang(self, target):
        print(f"Monster {self.jenis} menggigit {target}!")

    def info(self):
        print(f"Saya adalah Monster: {self.jenis}")

# -- Uji Coba --
# unit = GameUnit() # ERROR! Abstract class tidak bisa jadi objek.
h = Hero("Alucard")
m = Monster("Serigala")
h.info()
m.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2492/1301982501.py in <cell line: 0>()
#      32 # -- Uji Coba --
#      33 # unit = GameUnit() # ERROR! Abstract class tidak bisa jadi objek.
# ---> 34 h = Hero("Alucard")
#      35 m = Monster("Serigala")
#      36 h.info()
#
# TypeError: Can't instantiate abstract class Hero without an implementation for abstract method 'serang'

# %% [markdown]
#  #Can't instantiate abstract class Hero without an implementation for abstract method 'serang'
#  #Abstract class tidak bisa jadi objek belom memiliki implementasi

# %%
# Parent Class
class Hero:
    def __init__(self, nama):
        self.nama = nama

    def serang(self):
        print("Hero menyerang dengan tangan kosong.")

# Child Class 1
class Mage(Hero):
    def serang(self):
        print(f"{self.nama} (Mage) menembakkan Bola Api! Boom!")

# Child Class 2
class Archer(Hero):
    def tembak_panah(self):
        print(f"{self.nama} (Archer) memanah dari jauh! Jleb!")

# Child Class 3
class Fighter(Hero):
    def serang(self):
        print(f"{self.nama} (Fighter) memukul dengan pedang! Slash!")

# Child Class 4
class Healer(Hero): # Corrected 'hero' to 'Hero'
    def serang(self): # Changed 'serangan' to 'serang' for polymorphism
        print(f"{self.nama} (Healer) melakukan heal!")

# -- Penerapan Polymorphism --
# Kita punya daftar hero campuran
pasukan = [
    Mage("Eudora"),
    Archer("Miya"),
    Fighter("Zilong"),
    Mage("Gord"),
    Healer("estes")
]

print("--- PERANG DIMULAI ---")
# Satu perintah loop, tapi respon berbeda-beda (Polymorphism)
for pahlawan in pasukan:
    pahlawan.serang()
# Out:
# --- PERANG DIMULAI ---
# Eudora (Mage) menembakkan Bola Api! Boom!
# Hero menyerang dengan tangan kosong.
# Zilong (Fighter) memukul dengan pedang! Slash!
# Gord (Mage) menembakkan Bola Api! Boom!
# estes (Healer) melakukan heal!

# %% [markdown]
# program akan berjalan dengan lancar
# karna bila tidak sama akan memuculkan method lain

# %%
from abc import ABC, abstractmethod


# ==========================================
# ABSTRACT CLASS
# ==========================================
class KamarHotel(ABC):

    def __init__(self, nama_kamar, stok, harga_dasar):
        self.nama_kamar = nama_kamar
        self.__stok = stok
        self.__harga_dasar = harga_dasar

    # Getter untuk melihat stok
    def get_stok(self):
        return self.__stok

    # Getter untuk melihat harga dasar
    def get_harga_dasar(self):
        return self.__harga_dasar

    # Method untuk menambah/mengubah stok
    def tambah_stok(self, jumlah):
        stok_baru = self.__stok + jumlah

        if stok_baru < 0:
            print(
                f"Gagal update stok {self.nama_kamar}! "
                f"Stok tidak boleh negatif ({jumlah})."
            )
        else:
            self.__stok = stok_baru
            print(
                f"Berhasil menambahkan stok "
                f"{self.nama_kamar}: {jumlah} unit."
            )

    # Abstract Method
    @abstractmethod
    def tampilkan_detail(self):
        pass

    @abstractmethod
    def hitung_harga_total(self, jumlah_malam):
        pass


# ==========================================
# CHILD CLASS: KAMAR DELUXE
# ==========================================
class KamarDeluxe(KamarHotel):

    def __init__(self, nama_kamar, stok, harga_dasar, fasilitas):
        super().__init__(nama_kamar, stok, harga_dasar)
        self.fasilitas = fasilitas

    # Polymorphism / Override
    def tampilkan_detail(self):
        print(
            f"[DELUXE] {self.nama_kamar} | "
            f"Fasilitas: {self.fasilitas}"
        )

    # Pajak Deluxe = 10%
    def hitung_harga_total(self, jumlah_malam):
        harga = self.get_harga_dasar()
        pajak = harga * 0.10
        subtotal = (harga + pajak) * jumlah_malam

        return subtotal, pajak


# ==========================================
# CHILD CLASS: KAMAR STANDARD
# ==========================================
class KamarStandard(KamarHotel):

    def __init__(self, nama_kamar, stok, harga_dasar, kapasitas):
        super().__init__(nama_kamar, stok, harga_dasar)
        self.kapasitas = kapasitas

    # Polymorphism / Override
    def tampilkan_detail(self):
        print(
            f"[STANDARD] {self.nama_kamar} | "
            f"Kapasitas: {self.kapasitas}"
        )

    # Pajak Standard = 5%
    def hitung_harga_total(self, jumlah_malam):
        harga = self.get_harga_dasar()
        pajak = harga * 0.05
        subtotal = (harga + pajak) * jumlah_malam

        return subtotal, pajak


# ==========================================
# PROSES TRANSAKSI
# ==========================================
def proses_transaksi(daftar_pesanan):

    print("\n--- STRUK PEMESANAN ---")

    total_tagihan = 0

    for nomor, pesanan in enumerate(daftar_pesanan, start=1):

        kamar = pesanan["kamar"]
        jumlah_malam = pesanan["malam"]

        subtotal, pajak = kamar.hitung_harga_total(jumlah_malam)

        kamar.tampilkan_detail()

        print(
            f" Harga Dasar/Malam: "
            f"Rp {kamar.get_harga_dasar():,.0f} | "
            f"Pajak: Rp {pajak:,.0f}"
        )

        print(
            f" Menginap: {jumlah_malam} malam | "
            f"Subtotal: Rp {subtotal:,.0f}"
        )

        total_tagihan += subtotal

        print()

    print("----------------------------------------")
    print(f"TOTAL TAGIHAN: Rp {total_tagihan:,.0f}")
    print("----------------------------------------")


# ==========================================
# MAIN PROGRAM
# ==========================================

print("--- SETUP DATA KAMAR ---")

# Admin membuat kamar
deluxe = KamarDeluxe(
    "Kamar Deluxe Sea View",
    0,
    1_500_000,
    "Private Pool"
)

standard = KamarStandard(
    "Kamar Standard Superior",
    0,
    500_000,
    "2 Orang"
)

# Menambahkan stok Deluxe
deluxe.tambah_stok(10)

# Mencoba memasukkan stok negatif
standard.tambah_stok(-5)

# Menambahkan stok Standard
standard.tambah_stok(20)


# ==========================================
# PEMESANAN
# ==========================================

daftar_pesanan = [
    {
        "kamar": deluxe,
        "malam": 2
    },
    {
        "kamar": standard,
        "malam": 1
    }
]

proses_transaksi(daftar_pesanan)
# Out:
# --- SETUP DATA KAMAR ---
# Berhasil menambahkan stok Kamar Deluxe Sea View: 10 unit.
# Gagal update stok Kamar Standard Superior! Stok tidak boleh negatif (-5).
# Berhasil menambahkan stok Kamar Standard Superior: 20 unit.
#
# --- STRUK PEMESANAN ---
# [DELUXE] Kamar Deluxe Sea View | Fasilitas: Private Pool
#  Harga Dasar/Malam: Rp 1,500,000 | Pajak: Rp 150,000
#  Menginap: 2 malam | Subtotal: Rp 3,300,000
#
# [STANDARD] Kamar Standard Superior | Kapasitas: 2 Orang
#  Harga Dasar/Malam: Rp 500,000 | Pajak: Rp 25,000
#  Menginap: 1 malam | Subtotal: Rp 525,000
#
# ----------------------------------------
# TOTAL TAGIHAN: Rp 3,825,000
# ----------------------------------------
